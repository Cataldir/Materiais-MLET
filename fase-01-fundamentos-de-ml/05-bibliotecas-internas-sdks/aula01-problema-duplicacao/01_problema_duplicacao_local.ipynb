# %% [markdown]
# # Aula 01 - Problema de duplicacao
#
# Notebook local para visualizar hotspots de duplicacao antes de abstrair para uma biblioteca interna.

# %%
from duplication_problem import PIPELINES, build_hotspot_report

PIPELINES

# %%
hotspots = build_hotspot_report()
hotspots[:5]
