# %% [markdown]
# # Aula 02 - Prometheus e Grafana para APIs de ML
# Notebook local para exercitar o core de scoring da API instrumentada e relacionar previsoes com as metricas exportadas para Prometheus.

# %%
from api_instrumented import score_features

sample = [5.1, 3.5, 1.4, 0.2]
score_features(sample)

# %%
from api_instrumented import health

health()

# %% [markdown]
# ## Interpretacao
# Depois de subir a stack local, consulte `/metrics` na API e observe como latencia, contagem de predicoes e confianca podem alimentar paineis no Grafana.
