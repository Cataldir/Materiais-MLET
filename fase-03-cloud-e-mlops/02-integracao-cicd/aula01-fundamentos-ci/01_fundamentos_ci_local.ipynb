# %% [markdown]
# # Aula 01 - Fundamentos de CI para ML
# Notebook local para ler o workflow de CI preservado no pack e explicitar seu contrato minimo de validacao.

# %%
from ci_fundamentals import build_ci_lesson_summary

summary = build_ci_lesson_summary()
summary.workflow_name

# %%
[(stage.job_id, stage.display_name, stage.purpose) for stage in summary.stages]

# %% [markdown]
# ## Contrato local
# Use `summary.local_commands` para discutir quais checks o time deve conseguir executar antes do push e como isso reduz feedback tardio no workflow remoto.
