# %% [markdown]
# # Aula 03 - Testes e qualidade como gate
#
# Notebook local para observar checks individuais e a decisao final do gate de CI.

# %%
from ci_quality_tests import run_checks, gate_decision

checks = run_checks()
[(check.name, check.passed) for check in checks]

# %%
gate_decision(checks)
