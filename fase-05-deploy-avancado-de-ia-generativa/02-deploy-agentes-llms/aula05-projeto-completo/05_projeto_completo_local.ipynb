# %% [markdown]
# # Projeto completo local
# Notebook fino para executar o mesmo fluxo do modulo assistant_project.py.

# %% [markdown]
# # Projeto completo local
# Notebook fino para executar o mesmo fluxo do modulo assistant_project.py.

# %%
from assistant_project import run_assistant_demo
run_assistant_demo('Qual e a agenda do sprint local?')

# %%
run_assistant_demo('Quantos tickets cabem por turno?')

# %%
from assistant_project import run_assistant_demo
run_assistant_demo('Qual e a agenda do sprint local?')
