# %% [markdown]
# # Projeto avancado local
# Replay deterministico de workload com snapshots de fila.

# %% [markdown]
# # Projeto avancado local
# Replay deterministico de workload com snapshots de fila.

# %%
from advanced_project import run_advanced_project
run_advanced_project()

# %%
report = run_advanced_project()
report['snapshots'][-1]

# %%
from advanced_project import run_advanced_project
run_advanced_project()
