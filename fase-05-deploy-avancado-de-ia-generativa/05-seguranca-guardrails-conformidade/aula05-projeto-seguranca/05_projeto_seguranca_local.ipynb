# %% [markdown]
# # Projeto de seguranca local
# Pipeline de politicas e auditoria em memoria.

# %% [markdown]
# # Projeto de seguranca local
# Pipeline de politicas e auditoria em memoria.

# %%
from security_project import run_security_project
run_security_project()

# %%
report = run_security_project()
report['summary']

# %%
from security_project import run_security_project
run_security_project()
