# %% [markdown]
# # Aula 02 - Guardrails
#
# Notebook local para testar cenarios de allow, sanitize e block em prompts sinteticos.

# %%
from guardrails_demo import PROMPTS, apply_guardrails

PROMPTS

# %%
apply_guardrails()
