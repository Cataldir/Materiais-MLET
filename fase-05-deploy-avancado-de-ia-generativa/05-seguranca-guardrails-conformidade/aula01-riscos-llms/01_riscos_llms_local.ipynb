# %% [markdown]
# # Aula 01 - Riscos e ataques em LLMs
#
# Notebook local para priorizar riscos e conectar ameacas a controles futuros.

# %%
from llm_risks import build_risk_scenarios, prioritize_risks

build_risk_scenarios()

# %%
prioritize_risks()
