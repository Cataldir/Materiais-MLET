# %% [markdown]
# # Projeto LLMOps local
# Replay de traces com filtros pequenos e auditaveis.

# %% [markdown]
# # Projeto LLMOps local
# Replay de traces com filtros pequenos e auditaveis.

# %%
from llmops_project import run_llmops_project
run_llmops_project()

# %%
report = run_llmops_project()
report['summary']

# %%
from llmops_project import run_llmops_project
run_llmops_project()
