# %% [markdown]
# # Aula 03 - Tracing em LLMOps
#
# Notebook local para observar retrieval, prompt, generation e evaluation em um trace generativo unico.

# %%
from llm_tracing import build_rag_trace, compute_trace_metrics

trace = build_rag_trace()
trace

# %%
compute_trace_metrics(trace)
