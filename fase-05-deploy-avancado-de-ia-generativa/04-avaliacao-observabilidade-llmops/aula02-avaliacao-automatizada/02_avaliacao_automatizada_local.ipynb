# %% [markdown]
# # Aula 02 - Avaliacao automatizada
#
# Notebook local para comparar respostas grounded, parciais e alucinadas.

# %%
from ragas_evaluation import build_evaluation_cases, run_evaluation_demo

build_evaluation_cases()

# %%
run_evaluation_demo()
