# %% [markdown]
# # Aula 8 — Validação Contínua com MLOps (MLflow e Databricks)
#
# > **Nota:** Os exemplos práticos de MLOps desta aula estão contidos em um repositório separado:
# >
# > 👉 **[lfbraz/aula_validacao_dados_mlops](https://github.com/lfbraz/aula_validacao_dados_mlops)**
# >
# > Este repositório é um fork adaptado do **[databricks/mlops-stacks](https://github.com/databricks/mlops-stacks)**, o template oficial da Databricks para projetos de MLOps com CI/CD, registro de modelos e monitoramento contínuo.
# >
# > Clone o repositório acima e siga as instruções do `README.md` para executar os exemplos desta aula.
