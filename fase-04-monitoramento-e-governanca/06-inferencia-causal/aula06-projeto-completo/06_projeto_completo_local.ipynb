# %% [markdown]
# # Projeto Completo de Inferencia Causal
# Notebook integrador para consolidar DAG, uplift e recomendacoes prescritivas.

# %%
from causal_project import run_causal_project
summary = run_causal_project()
summary

# %%
for row in summary.rows:
    print(row.component, row.key_signal, row.decision)
print(summary.priority_queue)
