# %% [markdown]
# # Aula 02 - Pandera
# Notebook local para validar DataFrames tipados e observar o fallback quando Pandera nao estiver instalado.

# %%
from pandera_schemas import build_titanic_examples, run_validation_demo

valid_df, invalid_df = build_titanic_examples()
valid_df.head()

# %%
results = run_validation_demo()
results

# %% [markdown]
# ## Interpretacao
# Se `pandera_available` vier como `False`, o pack continua util para aula e testes locais, mas sem executar validacao real de schema.
