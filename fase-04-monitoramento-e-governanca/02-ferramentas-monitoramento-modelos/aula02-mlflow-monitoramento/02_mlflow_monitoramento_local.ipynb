# %% [markdown]
# # Aula 02 - MLflow para monitoramento continuo
#
# Notebook local para comparar batches estaveis, de watch e de alert em uma trilha de monitoramento.

# %%
from mlflow_monitoring import build_monitoring_batches, track_batches

build_monitoring_batches()

# %%
track_batches()
