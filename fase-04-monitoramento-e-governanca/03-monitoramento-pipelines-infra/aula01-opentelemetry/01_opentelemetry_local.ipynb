# %% [markdown]
# # Aula 01 - OpenTelemetry local
#
# Notebook local para visualizar spans de ingest, transform e train em um trace leve.

# %%
from otel_tracing import build_demo_trace, summarize_trace

build_demo_trace()

# %%
summarize_trace(build_demo_trace())
