# %% [markdown]
# # Aula 03 - Alerting local
#
# Notebook local para transformar snapshots em eventos de warning e critical com cooldown.

# %%
from alerting_demo import simulate_incident_timeline, run_alerting_demo

simulate_incident_timeline()

# %%
run_alerting_demo()
