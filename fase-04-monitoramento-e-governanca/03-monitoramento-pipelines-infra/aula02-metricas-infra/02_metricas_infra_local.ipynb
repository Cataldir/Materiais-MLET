# %% [markdown]
# # Aula 02 - Metricas de infraestrutura
#
# Notebook local para observar timeline de CPU, memoria e latencia em um pipeline sintetico.

# %%
from infra_metrics import generate_resource_timeline, compute_capacity_summary

samples = generate_resource_timeline()
samples

# %%
compute_capacity_summary(samples)
