# %% [markdown]
# # Aula 01 - LGPD e GDPR para ML
#
# Notebook local para classificar cenarios sinteticos entre allow, review e block.

# %%
from lgpd_compliance import build_use_cases, evaluate_cases

build_use_cases()

# %%
evaluate_cases()
