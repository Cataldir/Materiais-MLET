# %% [markdown]
# # Aula 03 - Model cards
#
# Notebook local para revisar as secoes minimas e o render do model card em Markdown.

# %%
from model_card_generator import MODEL_CARD, render_card, required_sections

required_sections()

# %%
render_card(MODEL_CARD)
