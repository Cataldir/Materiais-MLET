# %% [markdown]
# # Aula 01 - Tipos de Drift
# Notebook local para explorar data drift, concept drift e label drift com dados sinteticos.

# %%
from drift_simulator import build_scenarios, run_all_scenarios

scenarios = build_scenarios()
[scenario.name for scenario in scenarios]

# %%
summaries = run_all_scenarios()
for summary in summaries:
    print(summary.name)
    print('  drifted_features =', summary.drifted_features)
    print('  mean_shifts =', summary.mean_shifts)
    print('  label_rate_delta =', summary.label_rate_delta)

# %% [markdown]
# ## Leitura sugerida
# Use os resumos para discutir se a mudanca ocorreu nas features, no target ou na regra que relaciona ambos.
