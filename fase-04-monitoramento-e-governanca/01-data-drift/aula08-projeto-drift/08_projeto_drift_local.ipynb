# %% [markdown]
# # Projeto de Drift Local
# Notebook integrador para consolidar janelas, severidade e resposta operacional.

# %%
from drift_project import run_drift_project
summary = run_drift_project()
summary

# %%
for window in summary.windows:
    print(window.batch_name, window.severity, list(window.shifted_features), window.recommended_action)
