# %% [markdown]
# # Aula 01 - Problema de versionamento
#
# Notebook local para discutir reproducao, auditoria e rollback antes do uso de DVC e MLflow.

# %%
from versioning_problem import RUNS, count_reproducible_runs

[(run.name, run.is_reproducible()) for run in RUNS]

# %%
count_reproducible_runs()
